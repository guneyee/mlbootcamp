# %% [markdown]
# # 04 - Model Optimization
#
# This notebook focuses on hyperparameter optimization and model selection.
#
# ## Contents
# - Hyperparameter search space definition
# - Optimization strategy (Optuna/Grid Search)
# - Model comparison (LightGBM, XGBoost, CatBoost)
# - Best parameters selection
# - Performance improvements
