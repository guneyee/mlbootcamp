# %% [markdown]
# # 05 - Model Evaluation
#
# This notebook contains detailed model evaluation and interpretation.
#
# ## Contents
# - SHAP analysis
# - Feature importance
# - Error analysis by segments
# - Business threshold selection
# - Precision-Recall trade-offs
# - Model interpretability
