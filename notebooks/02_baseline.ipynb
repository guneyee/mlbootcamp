# %% [markdown]
# # 02 - Baseline Model
#
# This notebook contains baseline model training and evaluation.
#
# ## Contents
# - Basic preprocessing
# - Simple model training
# - Cross-validation
# - Baseline AUC score
# - Initial observations
