# %% [markdown]
# # 01 - Exploratory Data Analysis (EDA)
#
# This notebook contains exploratory data analysis for the Home Credit Default Risk dataset.
#
# ## Contents
# - Data loading and overview
# - Missing values analysis
# - Target distribution
# - Feature distributions
# - Correlations
# - Key findings
